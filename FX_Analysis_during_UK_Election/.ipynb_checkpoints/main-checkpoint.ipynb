# %% [markdown]
# # GBP/USD Exchange Rate during 2017 UK Election Night - Under Construction

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
from sklearn import linear_model, datasets
import statsmodels.api as sm

import pandas as pd
from collections import OrderedDict
from datetime import date

from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pylab

import tweepy

import json
# Out:
# C:\Users\AlexH\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
CONSUMER_KEY = '4BByuBKYk19fpSl5iMIkju3c0'
CONSUMER_SECRET = '2EK91aT0s7uMJ1oWECBRUwkXrxGykigrsmtqtOIAvFBPXiucQq'
ACCESS_TOKEN = '892729320736739328-E30nIY5dacqxeugxPoe3TXB2fIjITZB'
ACCESS_TOKEN_SECRET = 'WMViNA7y1d1trkb5nt7L5dOAHdScmYBMHm33sLeUVZrWT'


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

tweets_raw = api.user_timeline(screen_name = 'bbcelection', count = 200, include_rts = False)
for i in range(0,5):
    oldest=tweets_raw[-1].id
    new_tweets = api.user_timeline(screen_name = 'bbcelection',count=200,max_id=oldest)
    tweets_raw.extend(new_tweets)

data = [[tw.created_at.year, tw.created_at.month, tw.created_at.day,"%s.%s"%(tw.created_at.hour, tw.created_at.minute), tw.id_str, tw.text.encode("utf8")] for tw in tweets_raw ]
tweets=pd.DataFrame(data, columns=['year','month','date','time','tweet_id','tweet'])

# %%
# Wikipedia data
UKpoll = pd.read_csv('data/UK2017Poll.txt', sep='\t', header=0)
results = pd.read_csv("data/result.csv")

# %%
tweets
# Out:
#       year  month  date   time            tweet_id  \
# 0     2017      6     9  20.26  873275224090980352
# 1     2017      6     9  20.23  873274411654238209
# 2     2017      6     9  16.44  873219358939590656
# 3     2017      6     9  15.14  873196528923533312
# 4     2017      6     9   9.40  873112674753630212
# 5     2017      6     9   9.40  873112632907018240
# 6     2017      6     9   9.38  873112128621641729
# 7     2017      6     9   8.59  873102302113964033
# 8     2017      6     9   8.49  873099783061164033
# 9     2017      6     9   8.31  873095205984944129
# 10    2017      6     9   8.27  873094155068555266
# 11    2017      6     9   8.21  873092686340792320
# 12    2017      6     9    8.6  873088948326744064
# 13    2017      6     9    8.6  873088906438131712
# 14    2017      6     9   7.43  873083195981406208
# 15    2017      6     9   6.40  873067330468585472
# 16    2017      6     9   6.40  873067288898879488
# 17    2017      6     9   6.18  873061826765799425
# 18    2017      6     9   6.13  873060566402596864
# 19    2017      6     9   6.10  873059600412442626
# 20    2017      6     9    6.9  873059517029695489
# 21    2017      6     9    6.9  873059434271883265
# 22    2017      6     9    6.8  873059306941202433
# 23    2017      6     9    6.8  873059265413472257
# 24    2017      6     9   5.55  873055822028324864
# 25    2017      6     9   5.53  873055442963841024
# 26    2017      6     9   5.46  873053678785011714
# 27    2017      6     9   5.45  873053511138680834
# 28    2017      6     9   5.40  873052209054851074
# 29    2017      6     9   5.39  873051957304344578
# ...    ...    ...   ...    ...                 ...
# 1169  2016      6    24   1.26  746152420179324928
# 1170  2016      6    24   1.25  746152357172510720
# 1171  2016      6    24   1.25  746152327745273856
# 1172  2016      6    24   1.24  746152050019434496
# 1173  2016      6    24   1.22  746151522455650304
# 1174  2016      6    24   1.22  746151495008141314
# 1175  2016      6    24   1.19  746150838494715904
# 1176  2016      6    24   1.19  746150776129622016
# 1177  2016      6    24   1.19  746150747105001476
# 1178  2016      6    24   1.19  746150680595939328
# 1179  2016      6    24   1.19  746150650992549888
# 1180  2016      6    24   1.18  746150507421507584
# 1181  2016      6    24   1.17  746150183717773312
# 1182  2016      6    24   1.16  746150077153054720
# 1183  2016      6    24   1.13  746149208491696128
# 1184  2016      6    24   1.13  746149095220322305
# 1185  2016      6    24    1.8  746148022459994112
# 1186  2016      6    24    1.8  746147866276696064
# 1187  2016      6    24    1.7  746147634285527041
# 1188  2016      6    24    1.6  746147401661059072
# 1189  2016      6    24    1.6  746147335932108800
# 1190  2016      6    24    1.3  746146803821719553
# 1191  2016      6    24    1.3  746146693654134784
# 1192  2016      6    24    1.2  746146543309316097
# 1193  2016      6    24    1.2  746146522681729024
# 1194  2016      6    24    1.1  746146111153385472
# 1195  2016      6    24   0.59  746145585707753472
# 1196  2016      6    24   0.56  746145056860553216
# 1197  2016      6    24   0.56  746144817781014528
# 1198  2016      6    24   0.55  746144749560733696
#
#                                                   tweet
# 0     b'All the votes are counted, all the results a...
# 1     b'Kensington: LAB win #GE2017. Full results: h...
# 2     b'CORRECTION: Updated figures Southend West, C...
# 3     b'Update: Correcting LAB number of votes. Winc...
# 4     b'Update 10:40am: Latest seat totals by party ...
# 5     b'Updated result: Wells, CON hold #GE2017. See...
# 6     b'CORRECTION: Updated image Redditch CON hold ...
# 7     b'Update 9:59am: Latest seat totals by party #...
# 8     b'Update 9:49am: Latest seat totals by party #...
# 9     b'Update 9:31am: Latest seat totals by party #...
# 10    b'South East Cornwall: CON hold #GE2017. Full ...
# 11    b'Update 9:21am: Latest seat totals by party #...
# 12    b'Update 9:06am: Latest seat totals by party #...
# 13    b'St Austell: CON hold #GE2017. Full results: ...
# 14    b'Update 8:43am: Latest seat totals by party #...
# 15    b'Update 7:40am: Latest seat totals by party #...
# 16    b'St Ives: CON hold #GE2017. Full results: htt...
# 17    b'Update 7:18am: Latest seat totals by party #...
# 18    b'Dudley North: LAB hold #GE2017. Full results...
# 19    b'Newcastle-under-Lyme: LAB hold #GE2017. Full...
# 20    b'Crawley: CON hold #GE2017. Full results: htt...
# 21    b'Ashfield: LAB hold #GE2017. Full results: ht...
# 22    b'Update 7:08am: Latest seat totals by party #...
# 23    b'Richmond Park: CON win #GE2017. Full results...
# 24    b'Updated result: North West Hampshire, CON ho...
# 25    b'Ealing Southall: LAB hold #GE2017. Full resu...
# 26    b'Paisley and Renfrewshire North: SNP hold #GE...
# 27    b'Updated result: Glenrothes, SNP hold #GE2017...
# 28    b'Dorset West: CON hold #GE2017. Full results:...
# 29    b'Update 6:39am: Latest seat totals by party #...
# ...                                                 ...
# 1169  b'Burnley votes to Leave. Full results: https:...
# 1170  b'Bracknell Forest votes to Leave. Full result...
# 1171  b'Newport votes to Leave. Full results: https:...
# 1172  b'Falkirk votes to Remain. Full results: https...
# 1173  b'Stevenage votes to Leave. Full results: http...
# 1174  b'Glasgow votes to Remain. Full results: https...
# 1175  b'South Ayrshire votes to Remain. Full results...
# 1176  b'Oxford votes to Remain. Full results: https:...
# 1177  b'Lambeth votes to Remain. Full results: https...
# 1178  b'Exeter votes to Remain. Full results: https:...
# 1179  b'Stirling votes to Remain. Full results: http...
# 1180  b'Isle of Anglesey votes to Leave. Full result...
# 1181  b'Fareham votes to Leave. Full results: https:...
# 1182  b'North Warwickshire votes to Leave. Full resu...
# 1183  b'St. Helens votes to Leave. Full results: htt...
# 1184  b'Angus votes to Remain. Full results: https:/...
# 1185  b'Denbighshire votes to Leave. Full results: h...
# 1186  b'West Lothian votes to Remain. Full results: ...
# 1187  b'East Renfrewshire votes to Remain. Full resu...
# 1188  b'Redcar &amp; Cleveland votes to Leave. Full ...
# 1189  b'Eden votes to Leave. Full results: https://t...
# 1190  b'Harlow votes to Leave. Full results: https:/...
# 1191  b'Local result - North Down votes to Remain. F...
# 1192  b'Local result - Belfast West votes to Remain....
# 1193  b'Bury votes to Leave. Full results: https://t...
# 1194  b'Swansea votes to Leave. Full results: https:...
# 1195  b'Wellingborough votes to Leave. Full results:...
# 1196  b'Southend-on-Sea votes to Leave. Full results...
# 1197  b'Brentwood votes to Leave. Full results: http...
# 1198  b'Flintshire votes to Leave. Full results: htt...
#
# [1199 rows x 6 columns]
